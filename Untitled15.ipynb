# %% [markdown]
# <a href="https://colab.research.google.com/github/MAAZhashmi/Pandas/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns; sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b62fe152-0e6e-4187-a8ed-c82980e1bd4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b62fe152-0e6e-4187-a8ed-c82980e1bd4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cricket report.csv to cricket report.csv

# %%
df = pd.read_csv("cricket report.csv")

# %%
df.head(10)
# Out:
#    S. No               Player Runs Mins   BF 4s 6s     SR Inns
# 0   1578  AB de Villiers (SA)   36   84   60  4  0     60    1
# 1   1608  AB de Villiers (SA)   34   84   49  3  0  69.38    3
# 2   3891       AG Prince (SA)    0    2    3  0  0      0    1
# 3   3896       AG Prince (SA)   15   56   44  1  0  34.09    3
# 4   4784     AJ Strauss (ENG)    2    3    6  0  0  33.33    2
# 5   4796     AJ Strauss (ENG)   45  167  107  7  0  42.05    4
# 6   6098        AN Cook (ENG)   65  228  136  7  0  47.79    2
# 7   6127        AN Cook (ENG)   55  153  116  7  0  47.41    4
# 8  10971      BJ Haddin (AUS)    6   18    9  0  0  66.66    1
# 9  10993      BJ Haddin (AUS)   15   35   25  0  0     60    3

# %%
df.notnull()
# Out:
#        S. No  Player  Runs  Mins    BF    4s    6s    SR  Inns
# 0       True    True  True  True  True  True  True  True  True
# 1       True    True  True  True  True  True  True  True  True
# 2       True    True  True  True  True  True  True  True  True
# 3       True    True  True  True  True  True  True  True  True
# 4       True    True  True  True  True  True  True  True  True
# ...      ...     ...   ...   ...   ...   ...   ...   ...   ...
# 85883   True    True  True  True  True  True  True  True  True
# 85884   True    True  True  True  True  True  True  True  True
# 85885   True    True  True  True  True  True  True  True  True
# 85886   True    True  True  True  True  True  True  True  True
# 85887   True    True  True  True  True  True  True  True  True
#
# [85888 rows x 9 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (85888, 9)

# %%
df.columns
# Out:
# Index(['S. No', 'Player', 'Runs', 'Mins', 'BF', '4s', '6s', 'SR', 'Inns'], dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        S. No               Player Runs Mins  BF 4s 6s      SR Inns
# 0       1578  AB de Villiers (SA)   36   84  60  4  0      60    1
# 1       1608  AB de Villiers (SA)   34   84  49  3  0   69.38    3
# 2       3891       AG Prince (SA)    0    2   3  0  0       0    1
# 3       3896       AG Prince (SA)   15   56  44  1  0   34.09    3
# 4       4784     AJ Strauss (ENG)    2    3   6  0  0   33.33    2
# ...      ...                  ...  ...  ...  .. .. ..     ...  ...
# 85883  77346        TA Boult (NZ)   0*    3   0  0  0       -    1
# 85884  78682      TG Southee (NZ)   33   45  29  5  1  113.79    1
# 85885  80417      TWM Latham (NZ)    0    5   6  0  0       0    1
# 85886  83171        WA Young (NZ)   20   57  42  2  0   47.61    1
# 85887  85247      Z Crawley (ENG)    6   33  24  1  0      25    2
#
# [85888 rows x 9 columns]>

# %%
df.nunique()
# Out:
# S. No     85888
# Player     2991
# Runs        453
# Mins        554
# BF          413
# 4s           40
# 6s           19
# SR         5532
# Inns          5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85888 entries, 0 to 85887
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S. No   85888 non-null  int64
#  1   Player  85888 non-null  object
#  2   Runs    85888 non-null  object
#  3   Mins    85888 non-null  object
#  4   BF      85888 non-null  object
#  5   4s      85888 non-null  object
#  6   6s      85888 non-null  object
#  7   SR      85888 non-null  object
#  8   Inns    85888 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 5.9+ MB

# %%
print(df.isna().sum(axis = 0))
# Out:
# S. No     0
# Player    0
# Runs      0
# Mins      0
# BF        0
# 4s        0
# 6s        0
# SR        0
# Inns      0
# dtype: int64

# %%
df1 = df.groupby(['Player'],as_index=False)['4s','6s','SR','Runs']
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(df['Player'],df['Runs'])
plt.title("Player Vs Runs")
plt.xlabel("Player")
plt.ylabel("Runs")
plt.show()

# %%
plt.plot(df['Player'],df['6s'])
plt.title("Player Vs 6s ")
plt.xlabel("Player")
plt.ylabel(" 6s")
plt.show()

# %%
plt.plot(df['Player'],df['SR'])
plt.title("Player Vs SR")
plt.xlabel("Player")
plt.ylabel("SR")
plt.show()

# %%
plt.plot(df['Player'],df['6s'])
plt.title("Player Vs 6s")
plt.xlabel("player")
plt.ylabel("6s")
plt.show()

# %%
df1.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import seaborn as sns; sns.set(color_codes=True)

# %%
import seaborn as sns

sns.heatmap(df1.corr(), vmin=-1, vmax=1,
annot=True,cmap="rocket_r")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
